# %%
import pandas as pd
from alpaca_trade_api.rest import REST, TimeFrame
from dotenv import load_dotenv
import os
import alpaca_trade_api as tradeapi

apca_api_key = os.getenv("APCA_API_KEY_ID")
apca_secret_key = os.getenv("APCA_API_SECRET_KEY")

load_dotenv()

api = REST(apca_api_key, apca_secret_key)

# %%
api.get_quotes("AAPL", "2023-11-21", "2023-11-21", limit=10).df
# Out:
#                                      ask_price  ask_size ask_exchange  \
# timestamp
# 2023-11-21 00:00:45.014491313+00:00     191.54         2            Q
# 2023-11-21 00:00:45.020869896+00:00     191.54         2            Q
# 2023-11-21 00:00:47.156380966+00:00     191.54         2            Q
# 2023-11-21 00:01:00.656785501+00:00     191.54         1            Q
# 2023-11-21 00:01:14.571833111+00:00     191.53         1            P
# 2023-11-21 00:01:47.627775834+00:00     191.53         1            P
# 2023-11-21 00:01:47.634545202+00:00     191.53         1            P
# 2023-11-21 00:03:07.263054069+00:00     191.53         1            P
# 2023-11-21 00:03:48.383401994+00:00     191.54         1            Q
# 2023-11-21 00:04:04.823457257+00:00     191.54         1            Q
#
#                                      bid_price  bid_size bid_exchange  \
# timestamp
# 2023-11-21 00:00:45.014491313+00:00     191.50         5            P
# 2023-11-21 00:00:45.020869896+00:00     191.50         6            P
# 2023-11-21 00:00:47.156380966+00:00     191.51         1            P
# 2023-11-21 00:01:00.656785501+00:00     191.51         1            P
# 2023-11-21 00:01:14.571833111+00:00     191.51         1            P
# 2023-11-21 00:01:47.627775834+00:00     191.50         5            P
# 2023-11-21 00:01:47.634545202+00:00     191.52         1            P
# 2023-11-21 00:03:07.263054069+00:00     191.50         6            P
# 2023-11-21 00:03:48.383401994+00:00     191.50         6            P
# 2023-11-21 00:04:04.823457257+00:00     191.50         5            P
#
#                                     conditions tape
# timestamp
# 2023-11-21 00:00:45.014491313+00:00        [R]    C
# 2023-11-21 00:00:45.020869896+00:00        [R]    C
# 2023-11-21 00:00:47.156380966+00:00        [R]    C
# 2023-11-21 00:01:00.656785501+00:00        [R]    C
# 2023-11-21 00:01:14.571833111+00:00        [R]    C
# 2023-11-21 00:01:47.627775834+00:00        [R]    C
# 2023-11-21 00:01:47.634545202+00:00        [R]    C
# 2023-11-21 00:03:07.263054069+00:00        [R]    C
# 2023-11-21 00:03:48.383401994+00:00        [R]    C
# 2023-11-21 00:04:04.823457257+00:00        [R]    C
